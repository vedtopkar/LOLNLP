# %%
import pandas as pd
import urllib2
from bs4 import BeautifulSoup

url = 'http://giphy.com/search/angry/4?is=2'

categories = []
urls = ['http://giphy.com/search/bored/' + str(x) +'?is=2' for x in range(50)]

dfs = []
emotions = ['angry', 'bored', 'disappointed', 'drunk', 'embarassed', 
           'excited', 'frustrated', 'happy', 'hungry', 'inspired', 
           'lonely', 'love', 'nervous', 'pain', 'reaction', 'relaxed', 
           'sad', 'sassy', 'scared', 'shocked', 'sick', 'stressed', 
           'surprised', 'suspicious', 'tired', 'unimpressed']

for emotion in emotions:
    print emotion
    urls = ['http://giphy.com/search/' + emotion + '/' + str(x) +'?is=2' for x in range(100)]
    for url in urls:
        try:
            page = urllib2.urlopen(url).read()
            soup = BeautifulSoup(page)
            images = soup.findAll('div', class_='hoverable-gif')

            data = []
            for image in images:
                tags = [x.text.split('#')[1] for x in image.span.findAll('a')]
                url = image.a.figure.img['src'].replace('_s', '')
                dfs.append({'tags':tags, 'url':url, 'emotion': emotion})
        except:
            print 'Done with ' + emotion
            break
    
data = pd.DataFrame(dfs)
# Out:
# angry
# bored
# disappointed
# drunk
# embarassed
# excited
# frustrated
# happy
# hungry
# inspired
# lonely
# love
# nervous
# pain
# reaction
# relaxed
# sad
# sassy
# scared
# shocked
# sick
# stressed
# surprised
# suspicious
# tired
# unimpressed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-44f52a1e5144> in <module>()
#      45             break
#      46
# ---> 47 data = pd.concat(dfs).reset_index(drop=True)
#      48 data
#
# /Users/VedTopkar/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity)
#     715                        ignore_index=ignore_index, join=join,
#     716                        keys=keys, levels=levels, names=names,
# --> 717                        verify_integrity=verify_integrity)
#     718     return op.get_result()
#     719
#
# /Users/VedTopkar/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity)
#     766         for obj in objs:
#     767             if not isinstance(obj, NDFrame):
# --> 768                 raise TypeError("cannot concatenate a non-NDFrame object")
#     769
#     770             # consolidate
#
# TypeError: cannot concatenate a non-NDFrame object

# %%
pd.DataFrame(dfs)
# Out:
#            emotion                                               tags  \
# 0            angry                            [angry, horse, maximus]
# 1            angry                              [angry, taylor swift]
# 2            angry                           [angry, coach, throwing]
# 3            angry                                [angry, frustrated]
# 4            angry                     [angry, mario, nintendo, zoom]
# 5            angry                     [angry, spongebob squarepants]
# 6            angry                                 [angry, whoop ass]
# 7            angry        [angry, buffy the vampire slayer, the look]
# 8            angry                 [angry, barton fink, john goodman]
# 9            angry                   [angry, will ferrell, zoolander]
# 10           angry                  [adam demamp, angry, workaholics]
# 11           angry                             [angry, tom and jerry]
# 12           angry             [angry, pout, the emperors new groove]
# 13           angry                 [angry, fuck, furious, mark cuban]
# 14           angry                           [angry, up yours, x men]
# 15           angry  [angry, patrick, smashing, spongebob sqaurepants]
# 16           angry                  [angry, dump, pooping, wrestling]
# 17           angry                    [adam goldman, angry, the outs]
# 18           angry                          [angry, betty boop, whip]
# 19           angry             [angry, dexter, frustrated, screaming]
# 20           angry      [angry, frustrated, lauren conrad, the hills]
# 21           angry                  [angry, gene wilder, willy wonka]
# 22           angry                        [angry, conan obrien, hulk]
# 23           angry  [angry, fairuza balk, goth, screaming, the craft]
# 24           angry            [angry, dwight schrute, the office, tv]
# 25           angry                            [angry, horse, maximus]
# 26           angry                              [angry, taylor swift]
# 27           angry                           [angry, coach, throwing]
# 28           angry                                [angry, frustrated]
# 29           angry                     [angry, mario, nintendo, zoom]
# ...            ...                                                ...
# 39945  unimpressed                [cat, fui the cat, unimpressed cat]
# 39946  unimpressed  [cat, chicks, funny cat, grumpy cat, unimpress...
# 39947  unimpressed  [cat, crazy cat, funny cat, silly cat, unimpre...
# 39948  unimpressed  [cracked me up, geralt, geralt is so unimpress...
# 39949  unimpressed       [bags, carrying, explosion, fire, groceries]
# 39950  unimpressed  [bad girls club, bad girls club mexico, bgc, b...
# 39951  unimpressed  [bad girls club, bgc, bgc8, dani bgc, dani vic...
# 39952  unimpressed                                              [fan]
# 39953  unimpressed  [2014 world cup, england, finger gun, frown, f...
# 39954  unimpressed  [funy, miley cyrus, mtv vmas, music, reaction ...
# 39955  unimpressed    [jos manuel jurado, jose manuel jurado, jurado]
# 39956  unimpressed          [cm punk, nxt, nxt s1, this asshole, wwe]
# 39957  unimpressed          [cm punk, nxt, nxt s1, this asshole, wwe]
# 39958  unimpressed          [cm punk, nxt, nxt s1, this asshole, wwe]
# 39959  unimpressed          [cm punk, nxt, nxt s1, this asshole, wwe]
# 39960  unimpressed          [cm punk, nxt, nxt s1, this asshole, wwe]
# 39961  unimpressed          [cm punk, nxt, nxt s1, this asshole, wwe]
# 39962  unimpressed          [cm punk, nxt, nxt s1, this asshole, wwe]
# 39963  unimpressed          [cm punk, nxt, nxt s1, this asshole, wwe]
# 39964  unimpressed                [model, movies, natasha poly, rlvt]
# 39965  unimpressed    [12x08, james may, movies, series 12, top gear]
# 39966  unimpressed       [6x02, series 6, sports, the stig, top gear]
# 39967  unimpressed  [1980s movies, 80s movies, boy and alien, fred...
# 39968  unimpressed                  [malcolm tucker, the thick of it]
# 39969  unimpressed          [animals, biting, chew toy, dog, playing]
# 39970  unimpressed                                           [i lmao]
# 39971  unimpressed                 [celebs, mckayla maroney, rihanna]
# 39972  unimpressed                            [destiel, supernatural]
# 39973  unimpressed                                    [teen wolf, tv]
# 39974  unimpressed                                         [sherlock]
#
#                                                      url
# 0      http://media2.giphy.com/media/dOZj6qlD8Kwta/20...
# 1      http://media0.giphy.com/media/ORKQqVjegOvzq/20...
# 2      http://media2.giphy.com/media/110gOs75GuUWyY/2...
# 3      http://media0.giphy.com/media/yI9YaxO7OCz5K/20...
# 4      http://media0.giphy.com/media/kLEuIxZJh8VG0/20...
# 5      http://media2.giphy.com/media/90FH7I3McAQ7u/20...
# 6      http://media0.giphy.com/media/IzELwDFOUFCUw/20...
# 7      http://media0.giphy.com/media/vix9j7k0f9jPO/20...
# 8      http://media0.giphy.com/media/12tHi1VipCONeE/2...
# 9      http://media1.giphy.com/media/4xp6i71R08hAA/20...
# 10     http://media1.giphy.com/media/ua2LEJhsnNMxq/20...
# 11     http://media0.giphy.com/media/ntjBjvfnakKJ2/20...
# 12     http://media2.giphy.com/media/4y5JEsW1jcvKM/20...
# 13     http://media0.giphy.com/media/I3wsrN9ndx11m/20...
# 14     http://media3.giphy.com/media/BPE4CS4sb6mI0/20...
