# %% [markdown]
# #Sentiment Analysis
#
# Once we had all of our crowdsourced data that associates GIFs with emotions on the spectrum, we set out to create a sentiment analysis algorithm that can take an input string and associate it with an emotion. The first step is parts of speech tagging

# %%
import nltk
import numpy as np
import pandas as pd
from IPython import display

# %%
data1 = pd.read_csv('data/pos_tagged_gif_data.csv')
data2 = pd.read_csv('data/categorized_emotions.csv')
data = data1.merge(data2, left_on='URL', right_on='url')
data.head()
# Out:
#    Unnamed: 0_x  Unnamed: 0.1  \
# 0             2             2
# 1             3             3
# 2             7             7
# 3             7             7
# 4            14            14
#
#                                                 Text  \
# 0  3. Some days you hate every subject in the wor...
# 1  4. And other days you’re super ambitious and t...
# 2  8. Every time you speak to an adult they’re li...
# 3  8. Every time you speak to an adult they’re li...
# 4  15. And you’re just like, “Uhhhh well okay then.”
#
#                                                Title  \
# 0  18 Reasons Why Choosing A College Major Is Imp...
# 1  18 Reasons Why Choosing A College Major Is Imp...
# 2  18 Reasons Why Choosing A College Major Is Imp...
# 3  18 Reasons Why Choosing A College Major Is Imp...
# 4  18 Reasons Why Choosing A College Major Is Imp...
#
#                                                  URL  \
# 0  http://s3-ec.buzzfed.com/static/2014-05/enhanc...
# 1  http://s3-ec.buzzfed.com/static/2014-05/enhanc...
# 2  http://s3-ec.buzzfed.com/static/2014-05/enhanc...
# 3  http://s3-ec.buzzfed.com/static/2014-05/enhanc...
# 4  http://s3-ec.buzzfed.com/static/2014-05/enhanc...
#
#                                  text verbs      text adverbs  \
# 0            ['hate', 'decide', 'destined']          ['just']
# 1                           ['think', 'do']                []
# 2  ['speak', 'supposed', 'have', 'figured']    ['out', 'now']
# 3  ['speak', 'supposed', 'have', 'figured']    ['out', 'now']
# 4                                        []  ['just', 'well']
#
#                                     text adjectives  \
# 0                             ['you\xe2\x80\x99re']
# 1       ['other', 'you\xe2\x80\x99re', 'ambitious']
# 2  ['\xe2\x80\x9cso', 'major', 'you\xe2\x80\x99re']
# 3  ['\xe2\x80\x9cso', 'major', 'you\xe2\x80\x99re']
# 4        ['you\xe2\x80\x99re', '\xe2\x80\x9cUhhhh']
#
#                                           text nouns  \
# 0            ['days', 'subject', 'world', 'failure']
# 1           ['days', 'super', 'everything', 'world']
# 2  ['Every', 'time', 'adult', 'they\xe2\x80\x99re...
# 3  ['Every', 'time', 'adult', 'they\xe2\x80\x99re...
# 4                                           ['okay']
#
#                                        all text tags  \
# 0  [('3.', 'CD'), ('Some', 'DT'), ('days', 'NNS')...
# 1  [('4.', 'CD'), ('And', 'CC'), ('other', 'JJ'),...
# 2  [('8.', 'CD'), ('Every', 'NNP'), ('time', 'NN'...
# 3  [('8.', 'CD'), ('Every', 'NNP'), ('time', 'NN'...
# 4  [('15.', 'CD'), ('And', 'CC'), ('you\xe2\x80\x...
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                                          title nouns  \
# 0  ['Reasons', 'Choosing', 'College', 'Major', 'I...
# 1  ['Reasons', 'Choosing', 'College', 'Major', 'I...
# 2  ['Reasons', 'Choosing', 'College', 'Major', 'I...
# 3  ['Reasons', 'Choosing', 'College', 'Major', 'I...
# 4  ['Reasons', 'Choosing', 'College', 'Major', 'I...
#
#                                       all title tags Unnamed: 0_y    id  \
# 0  [('18', 'CD'), ('Reasons', 'NNS'), ('Why', 'WR...          830   714
# 1  [('18', 'CD'), ('Reasons', 'NNS'), ('Why', 'WR...         1215  1038
# 2  [('18', 'CD'), ('Reasons', 'NNS'), ('Why', 'WR...          292   319
# 3  [('18', 'CD'), ('Reasons', 'NNS'), ('Why', 'WR...          293  2611
# 4  [('18', 'CD'), ('Reasons', 'NNS'), ('Why', 'WR...          981   842
#
#   gif_id         x         y  \
# 0      4 -0.418667 -0.142857
# 1      5 -0.144000 -0.169173
# 2      9  0.148611  0.023438
# 3      9 -0.355172 -0.199029
# 4     16  0.434360  0.125571
#
#                                                  url  strength    emotion
# 0  http://s3-ec.buzzfed.com/static/2014-05/enhanc...  0.442369        sad
# 1  http://s3-ec.buzzfed.com/static/2014-05/enhanc...  0.222161  depressed
# 2  http://s3-ec.buzzfed.com/static/2014-05/enhanc...  0.150448   pleasant
# 3  http://s3-ec.buzzfed.com/static/2014-05/enhanc...  0.407136    unhappy
# 4  http://s3-ec.buzzfed.com/static/2014-05/enhanc...  0.452147      happy
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Training Classifier(s)
#
# When it comes to classifying text, binary classification schemas like Naive Bayes or Support Vector Machines (SVM) do pretty well. In order to adapt this to our schema of classifying text into one of the emotional categories, we decided to make $N$ classifiers, classifying text into or not into each of the $N$ emotional categories. Then, once these classifiers are trained, we can put an input string through each of the classifiers and aggregate the predictions to place the input string into one of the emotional categories.

# %%
data['Text'].astype(str)
# Out:
# 0     3. Some days you hate every subject in the wor...
# 1     4. And other days you’re super ambitious and t...
# 2     8. Every time you speak to an adult they’re li...
# 3     8. Every time you speak to an adult they’re li...
# 4     15. And you’re just like, “Uhhhh well okay then.”
# 5          16. And still, nothing seems to be clicking.
# 6     And Now For 8 "Mass Effect" Characters Dancing...
# 7                    Your link was successfully shared!
# 8                    Your link was successfully shared!
# 9                                             More Buzz
# 10    Note: once you save these links, they will no ...
# 11                                                  nan
# 12    3. Why does the old lady shoot her house to pi...
# 13     4. Why does the rats’ escape plan involve boats?
# 14    5. Why does Remy care so much about how the re...
# ...
# 3985    13. Irate customers have called you a “loser w...
# 3986        16. Holiday circulars make you want to vomit.
# 3987        16. Holiday circulars make you want to vomit.
# 3988           1. Cats Who Will Help You Write Your Novel
# 3989           1. Cats Who Will Help You Write Your Novel
# 3990              4. Does Badger ever become a TV writer?
# 3991    5. Where did the “Hello Kitty” phone case come...
# 3992           6. Did Hank ever finish “Leaves of Grass?”
# 3993    10. Did anyone ever try the table-side guacamole?
# 3994                          2. 2. Men are often idiots.
# 3995      3. 3. Sometimes all you have to do is be there.
# 3996                                  6. 6. Be ambitious.
# 3997            8. 8. And just to be safe, even a Plan C.
# 3998                12. 12. Always stick up for yourself.
# 3999              15. 15. It’s cool to have an alter ego.
# Name: Text, Length: 4000, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()

verbs = [x.replace('[', '').replace("'", '').replace(',', '').replace(']', '') for x in data['text verbs']]
nouns = [x.replace('[', '').replace("'", '').replace(',', '').replace(']', '') for x in data['text nouns']]
adverbs = [x.replace('[', '').replace("'", '').replace(',', '').replace(']', '') for x in data['text adverbs']]
adjectives = [x.replace('[', '').replace("'", '').replace(',', '').replace(']', '') for x in data['text adjectives']]

title_verbs = [x.replace('[', '').replace("'", '').replace(',', '').replace(']', '') for x in data['title verbs']]
title_nouns = [x.replace('[', '').replace("'", '').replace(',', '').replace(']', '') for x in data['title nouns']]
title_adverbs = [x.replace('[', '').replace("'", '').replace(',', '').replace(']', '') for x in data['title adverbs']]
title_adjectives = [x.replace('[', '').replace("'", '').replace(',', '').replace(']', '') for x in data['title adjectives']]

X = [verbs[i] + ' ' + nouns[i] + ' ' + title_verbs[i] + ' ' + title_nouns[i] + ' ' + title_adjectives[i] + ' ' + title_adverbs[i] + ' ' + adverbs[i] + ' ' + adjectives[i] for i in range(len(verbs))]
print X[:10]

X_train_counts = count_vect.fit_transform(X)
X_train_counts.shape
# Out:
# ['hate decide destined days subject world failure  Reasons Choosing College Major Is Impossible   just you\\xe2\\x80\\x99re', 'think do days super everything world  Reasons Choosing College Major Is Impossible    other you\\xe2\\x80\\x99re ambitious', 'speak supposed have figured Every time adult they\\xe2\\x80\\x99re what\\xe2\\x80\\x99s  Reasons Choosing College Major Is Impossible   out now \\xe2\\x80\\x9cso major you\\xe2\\x80\\x99re', 'speak supposed have figured Every time adult they\\xe2\\x80\\x99re what\\xe2\\x80\\x99s  Reasons Choosing College Major Is Impossible   out now \\xe2\\x80\\x9cso major you\\xe2\\x80\\x99re', ' okay  Reasons Choosing College Major Is Impossible   just well you\\xe2\\x80\\x99re \\xe2\\x80\\x9cUhhhh', 'seems be clicking nothing  Reasons Choosing College Major Is Impossible   still ', ' For Mass Effect Characters Dancing Like No One Watching  For Mass Effect Characters Dancing Like No One Watching  Now Now ', 'was shared link  For Mass Effect Characters Dancing Like No One Watching  Now successfully ', 'was shared link  For Mass Effect Characters Dancing Like No One Watching  Now successfully ', ' Buzz  For Mass Effect Characters Dancing Like No One Watching  Now  More']
# (4000, 5487)

# %%
# from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import SGDClassifier 
Y = np.asarray(data['emotion'], dtype="|S")
clf = SGDClassifier(n_iter=100)
clf.fit(X_train_counts, Y)
# Out:
# SGDClassifier(alpha=0.0001, class_weight=None, epsilon=0.1, eta0=0.0,
#        fit_intercept=True, l1_ratio=0.15, learning_rate='optimal',
#        loss='hinge', n_iter=100, n_jobs=1, penalty='l2', power_t=0.5,
#        random_state=None, rho=None, shuffle=False, verbose=0,
#        warm_start=False)

# %%
def get_relavent_gif(text):
    doc = count_vect.transform([text])
    predicted = clf.predict(doc)[0]
    print 'Predicted emotion: ' + str(predicted)
    
    filtered_urls = data[data['emotion'] == predicted]['url']
    i = np.random.choice(filtered_urls.index, 1)[0]
    url= filtered_urls.ix[i]
    display.display(display.Image(url=url))

get_relavent_gif('these are nice lights')
# Out:
# Predicted emotion: relaxed
# <img src="http://s3-ec.buzzfed.com/static/2014-08/7/23/enhanced/webdr05/anigif_enhanced-28202-1407467364-1.gif"/>

# %%
import nltk.corpus
import nltk.tokenize.punkt
import string
import re
 
# Create a set of stopwords based on the default NLTK english stopwords
# Be sure to also include punctuation and the empty string
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(string.punctuation)
stopwords.append('')

# Instantiate a tokenizer that tokenizes a given string
# Also instantiate the NLTK stemmer
tokenizer = nltk.tokenize.punkt.PunktWordTokenizer()
stemmer = nltk.stem.snowball.SnowballStemmer('english')
 
def check_matching_tokens(a, b):
    """
    A fuzzy matcher that sees if significant word stems match between two strings.
    Inspired by the examples here: http://bommaritollc.com/2014/06/fuzzy-match-sentences-python/
    """
    
    tokens_a = [token.lower().strip(string.punctuation) for token in tokenizer.tokenize(a) if token.lower().strip(string.punctuation) not in stopwords]
    stems_a = [stemmer.stem(token) for token in tokens_a]
    
    tokens_b = [token.lower().strip(string.punctuation) for token in tokenizer.tokenize(b) if token.lower().strip(string.punctuation) not in stopwords]
    stems_b = [stemmer.stem(token) for token in tokens_b]
    
    match = set(stems_a) & set(stems_b)
    return len(match)


def find_matching_gifs_by_content(input_string, data=data, output=True):
    """
    Given an input string and a master dataframe (data)
    Find the GIFs with matching tokenized content stems (ordered by number of matches)
    """
    
    matches = []
    
    # Iterate over each text and
    texts = data['Text'].fillna('')
    titles = data['Title'].fillna('')
    
    combined_text = [texts[i] + ' ' + titles[i] for i in range(len(data))]
    for text in combined_text:
        text = re.sub(r'[^\x00-\x7F]+',' ', text)
        n_matches = check_matching_tokens(text, input_string)
        matches.append({'Match': True if n_matches > 0 else False, 'n': n_matches })

    match_table = pd.DataFrame(matches)
    df = data.copy()
    df['Match'] = match_table['Match']
    df['N Matches'] = match_table['n']
    
    if np.sum(df['Match']) > 0:
        df = df[match_table['Match']].sort(columns='N Matches', ascending=False)
        max_n = max(df['N Matches'])
        df = df[df['N Matches'] == max_n]
        i = np.random.choice(df.index, 1)[0]
        url= df.ix[i]['url']
        t = df.ix[i]['Text']
        if output:
            print t, max_n
            display.display(display.Image(url=url))
        return df
    else:
        return []
    
find_matching_gifs_by_content('dance')
# Out:
# 14. Let me hear you say “scrub da ground” 1
# <img src="http://s3-ec.buzzfed.com/static/enhanced/webdr01/2013/5/23/17/anigif_enhanced-buzz-8091-1369342978-0.gif"/>
#       Unnamed: 0_x  Unnamed: 0.1  \
# 6               19            19
# 7               20            20
# 3140          6469          6469
# 3139          6469          6469
# 2571          5280          5280
# 2568          5270          5270
# 2218          4568          4568
# 2217          4567          4567
# 2216          4566          4566
# 2215          4565          4565
# 2214          4564          4564
# 2213          4562          4562
# 2204          4539          4539
# 2090          4334          4334
# 1823          3775          3775
# 1822          3775          3775
# 1800          3711          3711
# 3150          6490          6490
# 3159          6506          6506
# 3160          6506          6506
# 3486          7165          7165
# 3652          7507          7507
# 3498          7192          7192
# 3490          7168          7168
# 3489          7167          7167
# 3488          7165          7165
# 3487          7165          7165
# 3485          7159          7159
# 3161          6513          6513
# 3484          7159          7159
# ...            ...           ...
# 656           1333          1333
# 630           1287          1287
# 456            946           946
# 235            501           501
# 902           1807          1807
# 199            429           429
# 198            429           429
# 11              23            23
# 10              22            22
# 9               21            21
# 8               20            20
# 901           1806          1806
# 903           1809          1809
# 1796          3703          3703
# 1789          3692          3692
# 1795          3701          3701
# 1794          3700          3700
# 1793          3700          3700
# 1792          3695          3695
# 1791          3692          3692
# 1790          3692          3692
# 1788          3690          3690
# 904           1809          1809
# 1787          3690          3690
# 1786          3688          3688
# 1546          3183          3183
# 907           1814          1814
# 906           1814          1814
# 905           1810          1810
# 3662          7534          7534
#
#                                                    Text  \
# 6     And Now For 8 "Mass Effect" Characters Dancing...
# 7                    Your link was successfully shared!
# 3140                     And dancing!Tom strikes again!
# 3139                     And dancing!Tom strikes again!
# 2571                                  16. More dancing:
# 2568  6. Arguing because the DJ won’t play ‘Just Dan...
# 2218  We Could All Use More Dancing Shetland Ponies ...
# 2217                                      14. Spot. On.
# 2216  13. …and is basically Gob Bluth whilst doing a...
# 2215  12. And finally, Socks dances to “The Final Co...
# 2214  9. In this advert, Socks falls deeply in love ...
# 2213         5. …all through the faux, CGI countryside.
# 2204  5. When you go out, Alcohol is always your dan...
# 2090                     17. Voldemort can dance again.
# 1823           2. …and you have your own dance routine.
# 1822           2. …and you have your own dance routine.
# 1800  Watch the music video for her new single “Shak...
# 3150      18. We learned that white people can’t dance.
# 3159                        Press play and scroll down!
# 3160                        Press play and scroll down!
# 3486                    8. Fred Astaire’s Spirit Animal
# 3652             102. The “Anarchist Dance Troupe” Look
# 3498            22. 22. Veronica dancing with her crew.
# 3490                               11. The Limb Flailer
# 3489                       10. Beyonce’s Backing Dancer
# 3488                    8. Fred Astaire’s Spirit Animal
# 3487                    8. Fred Astaire’s Spirit Animal
# 3485                              2. The Secret Crunker
# 3161           7. Let me hear you say “scrub da ground”
# 3484                              2. The Secret Crunker
# ...                                                 ...
# 656                            6. She sings AND dances.
# 630                       6. 6. Dance like this at prom
# 456                          6. “……ilu future husband…”
# 235   2. Werk it, girl. Dancing naked in the privacy...
# 902   2. But the girls won’t go down without doing a...
# 199          28. When he showed off his dancing skills:
# 198          28. When he showed off his dancing skills:
# 11                                                  NaN
# 10    Note: once you save these links, they will no ...
# 9                                             More Buzz
# 8                    Your link was successfully shared!
# 901   1. Round 1: Taylor goes in first with a few sa...
# 903   4. But Taylor didn’t count on them knowing tha...
# 1796                               8. She can bunnyhop!
# 1789  19. Wait, is this an actual dance move? Hips d...
# 1795                                10. Spirit fingers!
# 1794                  11. Shake it off and reel ‘em in.
# 1793                  11. Shake it off and reel ‘em in.
# 1792  16. She’s got more limbs than she knows what t...
# 1791  19. Wait, is this an actual dance move? Hips d...
# 1790  19. Wait, is this an actual dance move? Hips d...
# 1788                  21. So grace. Much elegance. Wow.
# 904   4. But Taylor didn’t count on them knowing tha...
# 1787                  21. So grace. Much elegance. Wow.
# 1786         23. Check out that mildly tricky footwork!
# 1546     3. Sleeping Beauty on “Dancing with the Stars”
# 907                           9. Winner: Tegan and Sara
# 906                           9. Winner: Tegan and Sara
# 905   5. Round 3: Taylor goes all out, giving sassy ...
# 3662  75. The “Cute But Not Cute Enough To Distract ...
#
#                                                   Title  \
# 6     And Now For 8 "Mass Effect" Characters Dancing...
# 7     And Now For 8 "Mass Effect" Characters Dancing...
# 3140  10 Reasons "Thor: The Dark World" Is Really Th...
# 3139  10 Reasons "Thor: The Dark World" Is Really Th...
# 2571  27 GIFs That Prove Lumpy Space Princess From "...
# 2568  27 GIFs That Prove Lumpy Space Princess From "...
# 2218  We Could All Use More Dancing Shetland Ponies ...
# 2217  We Could All Use More Dancing Shetland Ponies ...
# 2216  We Could All Use More Dancing Shetland Ponies ...
# 2215  We Could All Use More Dancing Shetland Ponies ...
# 2214  We Could All Use More Dancing Shetland Ponies ...
# 2213  We Could All Use More Dancing Shetland Ponies ...
# 2204         25 Signs Alcohol Is Your Significant Other
# 2090  19 Reasons Why "A Very Potter Musical" Is Time...
# 1823  17 Signs You And Your Best Friend Are Turning ...
# 1822  17 Signs You And Your Best Friend Are Turning ...
# 1800  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 3150     33 Lessons Saturday Morning Cartoons Taught Us
# 3159             16 Animals Dancing To A '90s Booty Jam
# 3160             16 Animals Dancing To A '90s Booty Jam
# 3486           13 Dogs You Might See On The Dance Floor
# 3652  A Complete Ranking Of Everything Britney Spear...
# 3498  The 25 Best Moments Of The "Veronica Mars" Mov...
# 3490           13 Dogs You Might See On The Dance Floor
# 3489           13 Dogs You Might See On The Dance Floor
# 3488           13 Dogs You Might See On The Dance Floor
# 3487           13 Dogs You Might See On The Dance Floor
# 3485           13 Dogs You Might See On The Dance Floor
# 3161             16 Animals Dancing To A '90s Booty Jam
# 3484           13 Dogs You Might See On The Dance Floor
# ...                                                 ...
# 656   15 Reasons Jessica Lange Should Stay On "Ameri...
# 630   20 Things You Wanted To Do In High School But ...
# 456   And Now For Martin Freeman Dancing Awkwardly I...
# 235    18 Flawless Beauty Tips From "Fantasia" Centaurs
# 902   Watch Taylor Swift Challenge Tegan And Sara To...
# 199       29 Times Harry Styles Was Actually The Cutest
# 198       29 Times Harry Styles Was Actually The Cutest
# 11    And Now For 8 "Mass Effect" Characters Dancing...
# 10    And Now For 8 "Mass Effect" Characters Dancing...
# 9     And Now For 8 "Mass Effect" Characters Dancing...
# 8     And Now For 8 "Mass Effect" Characters Dancing...
# 901   Watch Taylor Swift Challenge Tegan And Sara To...
# 903   Watch Taylor Swift Challenge Tegan And Sara To...
# 1796  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 1789  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 1795  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 1794  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 1793  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 1792  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 1791  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 1790  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 1788  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 904   Watch Taylor Swift Challenge Tegan And Sara To...
# 1787  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 1786  27 GIFs Of Taylor Swift Dancing Awkwardly In H...
# 1546         If Disney Princesses Were Reality TV Stars
# 907   Watch Taylor Swift Challenge Tegan And Sara To...
# 906   Watch Taylor Swift Challenge Tegan And Sara To...
# 905   Watch Taylor Swift Challenge Tegan And Sara To...
# 3662  A Complete Ranking Of Everything Britney Spear...
#
#                                                     URL  \
# 6     http://s3-ec.buzzfed.com/static/2013-10/enhanc...
# 7     http://s3-ec.buzzfed.com/static/2013-10/enhanc...
# 3140  http://s3-ec.buzzfed.com/static/2013-11/enhanc...
# 3139  http://s3-ec.buzzfed.com/static/2013-11/enhanc...
# 2571  http://s3-ec.buzzfed.com/static/2014-07/29/21/...
# 2568  http://s3-ec.buzzfed.com/static/2014-07/29/21/...
# 2218  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 2217  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 2216  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 2215  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 2214  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 2213  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 2204  http://s3-ec.buzzfed.com/static/2013-12/enhanc...
# 2090  http://s3-ec.buzzfed.com/static/2014-06/29/23/...
# 1823  http://s3-ec.buzzfed.com/static/2013-10/enhanc...
# 1822  http://s3-ec.buzzfed.com/static/2013-10/enhanc...
# 1800  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 3150  http://s3-ec.buzzfed.com/static/2014-03/enhanc...
# 3159  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 3160  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 3486  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 3652  http://s3-ec.buzzfed.com/static/2014-07/16/21/...
# 3498  http://s3-ec.buzzfed.com/static/2014-01/enhanc...
# 3490  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 3489  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 3488  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 3487  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 3485  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 3161  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 3484  http://s3-ec.buzzfed.com/static/enhanced/webdr...
# ...                                                 ...
# 656   http://s3-ec.buzzfed.com/static/2014-09/25/0/e...
# 630   http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 456   http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 235   http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 902   http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 199   http://s3-ec.buzzfed.com/static/2014-02/enhanc...
# 198   http://s3-ec.buzzfed.com/static/2014-02/enhanc...
# 11    http://s3-ec.buzzfed.com/static/2013-10/enhanc...
# 10    http://s3-ec.buzzfed.com/static/2013-10/enhanc...
# 9     http://s3-ec.buzzfed.com/static/2013-10/enhanc...
# 8     http://s3-ec.buzzfed.com/static/2013-10/enhanc...
# 901   http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 903   http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 1796  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 1789  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 1795  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 1794  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 1793  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 1792  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 1791  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 1790  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 1788  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 904   http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 1787  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 1786  http://s3-ec.buzzfed.com/static/2014-08/18/18/...
# 1546  http://s3-ec.buzzfed.com/static/2013-10/enhanc...
# 907   http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 906   http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 905   http://s3-ec.buzzfed.com/static/enhanced/webdr...
# 3662  http://s3-ec.buzzfed.com/static/2014-07/16/20/...
#
#                           text verbs  \
# 6                                 []
# 7                  ['was', 'shared']
# 3140          ['dancing', 'strikes']
# 3139          ['dancing', 'strikes']
# 2571                              []
# 2568                              []
# 2218                         ['All']
# 2217                              []
# 2216                 ['is', 'doing']
# 2215                              []
# 2214                              []
# 2213                              []
# 2204                    ['go', 'is']
# 2090                       ['dance']
# 1823                        ['have']
# 1822                        ['have']
# 1800                         ['see']
# 3150                     ['learned']
# 3159                              []
# 3160                              []
# 3486                        ['Fred']
# 3652                              []
# 3498                              []
# 3490                              []
# 3489                              []
# 3488                        ['Fred']
# 3487                        ['Fred']
# 3485                              []
# 3161                 ['hear', 'say']
# 3484                              []
# ...                              ...
# 656                        ['sings']
# 630                               []
# 456                               []
# 235                        ['naked']
# 902                        ['doing']
# 199                       ['showed']
# 198                       ['showed']
# 11                                []
# 10                  ['Note', 'save']
# 9                                 []
# 8                  ['was', 'shared']
# 901                         ['goes']
# 903                      ['knowing']
# 1796                    ['bunnyhop']
# 1789                          ['is']
# 1795                              []
# 1794                              []
# 1793                              []
# 1792          ['got', 'knows', 'do']
# 1791                          ['is']
# 1790                          ['is']
# 1788                              []
# 904                      ['knowing']
# 1787                              []
# 1786                              []
# 1546                              []
# 907                               []
# 906                               []
# 905   ['goes', 'giving', 'audience']
# 3662                              []
#
#                                    text adverbs  \
# 6                                       ['Now']
# 7                              ['successfully']
# 3140                                  ['again']
# 3139                                  ['again']
# 2571                                         []
# 2568                                         []
# 2218                                         []
# 2217                                         []
# 2216                              ['basically']
# 2215                                ['finally']
# 2214                                 ['deeply']
# 2213                                         []
# 2204                          ['out', 'always']
# 2090                                  ['again']
# 1823                                         []
# 1822                                         []
# 1800                          ['intentionally']
# 3150                                         []
# 3159                                         []
# 3160                                         []
# 3486                                         []
# 3652                                         []
# 3498                                         []
# 3490                                         []
# 3489                                         []
# 3488                                         []
# 3487                                         []
# 3485                                         []
# 3161                                         []
# 3484                                         []
# ...                                         ...
# 656                                          []
# 630                                          []
# 456                                          []
# 235                                          []
# 902                                          []
# 199                                     ['off']
# 198                                     ['off']
# 11                                           []
# 10    ['once', 'no', 'longer', 'automatically']
# 9                                            []
# 8                              ['successfully']
# 901                                          []
# 903                                     ['too']
# 1796                                         []
# 1789                                         []
# 1795                                         []
# 1794                                         []
# 1793                                         []
# 1792                                         []
# 1791                                         []
# 1790                                         []
# 1788                                     ['So']
# 904                                     ['too']
# 1787                                     ['So']
# 1786                                 ['mildly']
# 1546                                         []
# 907                                          []
# 906                                          []
# 905                                          []
# 3662                                    ['Not']
#
#                                         text adjectives  \
# 6                                                    []
# 7                                                    []
# 3140                                                 []
# 3139                                                 []
# 2571                               ['More', 'dancing:']
# 2568                               ['\xe2\x80\x98Just']
# 2218                                                 []
# 2217                                                 []
# 2216  ['\xe2\x80\xa6and', '\xe2\x80\x9cillusion.\xe2...
# 2215                                                 []
# 2214                              ['\xe2\x80\x9cTotal']
# 2213                                ['\xe2\x80\xa6all']
# 2204                                                 []
# 2090                                                 []
# 1823                         ['\xe2\x80\xa6and', 'own']
# 1822                         ['\xe2\x80\xa6and', 'own']
# 1800                                     ['new', 'bad']
# 3150                      ['white', 'can\xe2\x80\x99t']
# 3159                                                 []
# 3160                                                 []
# 3486                                                 []
# 3652                          ['\xe2\x80\x9cAnarchist']
# 3498                                                 []
# 3490                                                 []
# 3489                                                 []
# 3488                                                 []
# 3487                                                 []
# 3485                                                 []
# 3161                                                 []
# 3484                                                 []
# ...                                                 ...
# 656                                                  []
# 630                                                  []
# 456   ['\xe2\x80\x9c\xe2\x80\xa6\xe2\x80\xa6ilu', 'f...
# 235                                        ['all-girl']
# 902                  ['won\xe2\x80\x99t', 'few', 'own']
# 199                                                  []
# 198                                                  []
# 11                                                   []
# 10                                           ['update']
# 9                                              ['More']
# 8                                                    []
# 901                           ['first', 'few', 'sassy']
# 903                                                  []
# 1796                                                 []
# 1789                                         ['actual']
# 1795                                                 []
# 1794                                                 []
# 1793                                                 []
# 1792                                           ['more']
# 1791                                         ['actual']
# 1790                                         ['actual']
# 1788                                                 []
# 904                                                  []
# 1787                                                 []
# 1786                                         ['tricky']
# 1546       ['\xe2\x80\x9cDancing', 'Stars\xe2\x80\x9d']
# 907                                                  []
# 906                                                  []
# 905                                           ['sassy']
# 3662          ['\xe2\x80\x9cCute', 'Less-Than-Stellar']
#
#                                              text nouns  \
# 6     ['For', 'Mass', 'Effect', 'Characters', 'Danci...
# 7                                              ['link']
# 3140                                            ['Tom']
# 3139                                            ['Tom']
# 2571                                                 []
# 2568  ['Arguing', 'DJ', 'won\xe2\x80\x99t', 'play', ...
# 2218  ['Use', 'More', 'Dancing', 'Shetland', 'Ponies...
# 2217                                    ['Spot.', 'On']
# 2216                         ['Gob', 'Bluth', 'whilst']
# 2215  ['Socks', 'dances', '\xe2\x80\x9cThe', 'Final'...
# 2214  ['advert', 'Socks', 'falls', 'love', 'dances',...
# 2213                     ['faux', 'CGI', 'countryside']
# 2204                    ['Alcohol', 'dance', 'partner']
# 2090                                      ['Voldemort']
# 1823                               ['dance', 'routine']
# 1822                               ['dance', 'routine']
# 1800  ['Watch', 'music', 'video', 'single', '\xe2\x8...
# 3150                                ['people', 'dance']
# 3159                        ['Press', 'play', 'scroll']
# 3160                        ['Press', 'play', 'scroll']
# 3486                               ['Spirit', 'Animal']
# 3652            ['Dance', 'Troupe\xe2\x80\x9d', 'Look']
# 3498                    ['Veronica', 'dancing', 'crew']
# 3490                                ['Limb', 'Flailer']
# 3489      ['Beyonce\xe2\x80\x99s', 'Backing', 'Dancer']
# 3488                               ['Spirit', 'Animal']
# 3487                               ['Spirit', 'Animal']
# 3485                              ['Secret', 'Crunker']
# 3161                                      ['Let', 'da']
# 3484                              ['Secret', 'Crunker']
# ...                                                 ...
# 656                                          ['dances']
# 630                                   ['Dance', 'prom']
# 456                 ['husband\xe2\x80\xa6\xe2\x80\x9d']
# 235   ['Werk', 'girl.', 'Dancing', 'privacy', 'harem...
# 902                                     ['girls', 'go']
# 199                                         ['dancing']
# 198                                         ['dancing']
# 11                                                   []
# 10                                            ['links']
# 9                                              ['Buzz']
# 8                                              ['link']
# 901             ['Round', 'Taylor', 'shoulder', 'pops']
# 903            ['Taylor', 'didn\xe2\x80\x99t', 'count']
# 1796                                                 []
# 1789  ['Wait', 'dance', 'move', 'Hips', 'don\xe2\x80...
# 1795                              ['Spirit', 'fingers']
# 1794                ['Shake', 'reel', '\xe2\x80\x98em']
# 1793                ['Shake', 'reel', '\xe2\x80\x98em']
# 1792                      ['She\xe2\x80\x99s', 'limbs']
# 1791  ['Wait', 'dance', 'move', 'Hips', 'don\xe2\x80...
# 1790  ['Wait', 'dance', 'move', 'Hips', 'don\xe2\x80...
# 1788             ['grace.', 'Much', 'elegance.', 'Wow']
# 904            ['Taylor', 'didn\xe2\x80\x99t', 'count']
# 1787             ['grace.', 'Much', 'elegance.', 'Wow']
# 1786                              ['Check', 'footwork']
# 1546                             ['Sleeping', 'Beauty']
# 907                         ['Winner', 'Tegan', 'Sara']
# 906                         ['Winner', 'Tegan', 'Sara']
# 905                        ['Round', 'Taylor', 'looks']
# 3662  ['Cute', 'Enough', 'To', 'Distract', 'From', '...
#
#                                           all text tags  \
# 6     [('And', 'CC'), ('Now', 'RB'), ('For', 'NNP'),...
# 7     [('Your', 'PRP$'), ('link', 'NN'), ('was', 'VB...
# 3140  [('And', 'CC'), ('dancing', 'VBG'), ('!', '.')...
# 3139  [('And', 'CC'), ('dancing', 'VBG'), ('!', '.')...
# 2571  [('16.', 'CD'), ('More', 'JJR'), ('dancing:', ...
# 2568  [('6.', 'CD'), ('Arguing', 'NNP'), ('because',...
# 2218  [('We', 'PRP'), ('Could', 'MD'), ('All', 'VB')...
# 2217  [('14.', 'CD'), ('Spot.', 'NNP'), ('On', 'NNP'...
# 2216  [('13.', 'CD'), ('\xe2\x80\xa6and', 'JJ'), ('i...
# 2215  [('12.', 'CD'), ('And', 'CC'), ('finally', 'RB...
# 2214  [('9.', 'CD'), ('In', 'IN'), ('this', 'DT'), (...
# 2213  [('5.', 'CD'), ('\xe2\x80\xa6all', 'JJ'), ('th...
# 2204  [('5.', 'CD'), ('When', 'WRB'), ('you', 'PRP')...
# 2090  [('17.', 'CD'), ('Voldemort', 'NNP'), ('can', ...
# 1823  [('2.', 'CD'), ('\xe2\x80\xa6and', 'JJ'), ('yo...
# 1822  [('2.', 'CD'), ('\xe2\x80\xa6and', 'JJ'), ('yo...
# 1800  [('Watch', 'NN'), ('the', 'DT'), ('music', 'NN...
# 3150  [('18.', 'CD'), ('We', 'PRP'), ('learned', 'VB...
# 3159  [('Press', 'NN'), ('play', 'NN'), ('and', 'CC'...
# 3160  [('Press', 'NN'), ('play', 'NN'), ('and', 'CC'...
# 3486  [('8.', 'CD'), ('Fred', 'VBN'), ('Astaire\xe2\...
# 3652  [('102.', 'CD'), ('The', 'DT'), ('\xe2\x80\x9c...
# 3498  [('22.', 'CD'), ('22.', 'CD'), ('Veronica', 'N...
# 3490  [('11.', 'CD'), ('The', 'DT'), ('Limb', 'NNP')...
# 3489  [('10.', 'CD'), ('Beyonce\xe2\x80\x99s', 'NNS'...
# 3488  [('8.', 'CD'), ('Fred', 'VBN'), ('Astaire\xe2\...
# 3487  [('8.', 'CD'), ('Fred', 'VBN'), ('Astaire\xe2\...
# 3485  [('2.', 'CD'), ('The', 'DT'), ('Secret', 'NNP'...
# 3161  [('7.', 'CD'), ('Let', 'NNP'), ('me', 'PRP'), ...
# 3484  [('2.', 'CD'), ('The', 'DT'), ('Secret', 'NNP'...
# ...                                                 ...
# 656   [('6.', 'CD'), ('She', 'PRP'), ('sings', 'VBZ'...
# 630   [('6.', 'CD'), ('6.', 'CD'), ('Dance', 'NNP'),...
# 456   [('6.', 'CD'), ('\xe2\x80\x9c\xe2\x80\xa6\xe2\...
# 235   [('2.', 'CD'), ('Werk', 'NNP'), ('it', 'PRP'),...
# 902   [('2.', 'CD'), ('But', 'CC'), ('the', 'DT'), (...
# 199   [('28.', 'CD'), ('When', 'WRB'), ('he', 'PRP')...
# 198   [('28.', 'CD'), ('When', 'WRB'), ('he', 'PRP')...
# 11                                                   []
# 10    [('Note', 'VB'), (':', ':'), ('once', 'RB'), (...
# 9                    [('More', 'JJR'), ('Buzz', 'NNP')]
# 8     [('Your', 'PRP$'), ('link', 'NN'), ('was', 'VB...
# 901   [('1.', 'CD'), ('Round', 'NNP'), ('1', 'CD'), ...
# 903   [('4.', 'CD'), ('But', 'CC'), ('Taylor', 'NNP'...
# 1796  [('8.', 'CD'), ('She', 'PRP'), ('can', 'MD'), ...
# 1789  [('19.', 'CD'), ('Wait', 'NNP'), (',', ','), (...
# 1795  [('10.', 'CD'), ('Spirit', 'NN'), ('fingers', ...
# 1794  [('11.', 'CD'), ('Shake', 'NNP'), ('it', 'PRP'...
# 1793  [('11.', 'CD'), ('Shake', 'NNP'), ('it', 'PRP'...
# 1792  [('16.', 'CD'), ('She\xe2\x80\x99s', 'NNS'), (...
# 1791  [('19.', 'CD'), ('Wait', 'NNP'), (',', ','), (...
# 1790  [('19.', 'CD'), ('Wait', 'NNP'), (',', ','), (...
# 1788  [('21.', 'CD'), ('So', 'RB'), ('grace.', 'NNP'...
# 904   [('4.', 'CD'), ('But', 'CC'), ('Taylor', 'NNP'...
# 1787  [('21.', 'CD'), ('So', 'RB'), ('grace.', 'NNP'...
# 1786  [('23.', 'CD'), ('Check', 'NNP'), ('out', 'IN'...
# 1546  [('3.', 'CD'), ('Sleeping', 'NNP'), ('Beauty',...
# 907   [('9.', 'CD'), ('Winner', 'NNP'), (':', ':'), ...
# 906   [('9.', 'CD'), ('Winner', 'NNP'), (':', ':'), ...
# 905   [('5.', 'CD'), ('Round', 'NNP'), ('3', 'CD'), ...
# 3662  [('75.', 'CD'), ('The', 'DT'), ('\xe2\x80\x9cC...
#
#                             ...                         Unnamed: 0_y    id  \
# 6                           ...                                 2818  2538
# 7                           ...                                 3637  3549
# 3140                        ...                                  227  1349
# 3139                        ...                                  226   272
# 2571                        ...                                 2312  2030
# 2568                        ...                                  221   267
# 2218                        ...                                 3580  3458
# 2217                        ...                                 3852  3891
# 2216                        ...                                 2269  1988
# 2215                        ...                                 3021  2775
# 2214                        ...                                 2061  1778
# 2213                        ...                                 2224  1942
# 2204                        ...                                 3342  3155
# 2090                        ...                                 2225  1943
# 1823                        ...                                 3322  3471
# 1822                        ...                                 3321  3130
# 1800                        ...                                  858  3349
# 3150                        ...                                 2949  2692
# 3159                        ...                                  169   233
# 3160                        ...                                  170  3574
# 3486                        ...                                  851   727
# 3652                        ...                                 3273  3070
# 3498                        ...                                 2565  2263
# 3490                        ...                                 3235  3024
# 3489                        ...                                 1820  1565
# 3488                        ...                                  853  2847
# 3487                        ...                                  852  1350
# 3485                        ...                                  653  3052
# 3161                        ...                                 2469  2172
# 3484                        ...                                  652   576
# ...                         ...                                  ...   ...
# 656                         ...                                 1576  1328
# 630                         ...                                 2369  2083
# 456                         ...                                 3258  3053
# 235                         ...                                  938   802
# 902                         ...                                 2143  1860
# 199                         ...                                 1602  1583
# 198                         ...                                 1601  1351
# 11                          ...                                 1961  1686
# 10                          ...                                 2136  1848
# 9                           ...                                 2670  2378
# 8                           ...                                 3638  3887
# 901                         ...                                 2397  2112
# 903                         ...                                 3198  2983
# 1796                        ...                                 1643  1391
# 1789                        ...                                  395   390
# 1795                        ...                                 1034   885
# 1794                        ...                                 1568  2129
# 1793                        ...                                 1567  1322
# 1792                        ...                                 1958  1683
# 1791                        ...                                  397  2670
# 1790                        ...                                  396  2669
# 1788                        ...                                 3212  3367
# 904                         ...                                 3199  3710
# 1787                        ...                                 3211  2993
# 1786                        ...                                 1720  1463
# 1546                        ...                                 3366  3184
# 907                         ...                                 2479  2184
# 906                         ...                                 2478  2182
# 905                         ...                                 2485  2188
# 3662                        ...                                 3805  3811
#
#      gif_id         x         y  \
# 6        21 -0.368056  0.035156
# 7        22  0.318000 -0.075188
# 3140   6471  0.378667 -0.304511
# 3139   6471 -0.002667 -0.112782
# 2571   5282  0.407639 -0.035156
# 2568   5272 -0.004000  0.003759
# 2218   4570  0.372464  0.327869
# 2217   4569 -0.440000  0.093985
# 2216   4568  0.460000 -0.041353
# 2215   4567  0.388000 -0.131579
# 2214   4566  0.002667  0.157895
# 2213   4564  0.453333 -0.157895
# 2204   4541  0.454667 -0.041353
# 2090   4336  0.436000  0.135338
# 1823   3777  0.447826 -0.188525
# 1822   3777  0.298667 -0.304511
# 1800   3713 -0.304700 -0.376712
# 3150   6492 -0.210000  0.406015
# 3159   6508  0.080667 -0.345865
# 3160   6508  0.244667 -0.251880
# 3486   7167  0.282000 -0.398496
# 3652   7509 -0.394667  0.097744
# 3498   7194 -0.014583 -0.472656
# 3490   7170  0.293333 -0.368421
# 3489   7169  0.303571 -0.298165
# 3488   7167  0.292667 -0.349624
# 3487   7167  0.217532 -0.284404
# 3485   7161 -0.001621 -0.376712
# 3161   6515  0.479333 -0.481203
# 3484   7161 -0.359722 -0.288235
# ...     ...       ...       ...
# 656    1335  0.356000 -0.052632
# 630    1289  0.295333 -0.161654
# 456     948  0.275527 -0.331050
# 235     503 -0.149109  0.431507
# 902    1809  0.000000 -0.018797
# 199     431  0.134740  0.399083
# 198     431  0.250000 -0.183486
# 11       25  0.406250  0.148438
# 10       24  0.029333 -0.206767
# 9        23  0.060000 -0.018797
# 8        22  0.297333 -0.233083
# 901    1808  0.439222 -0.207763
# 903    1811  0.169368 -0.230594
# 1796   3705  0.081169 -0.114679
# 1789   3694 -0.180556  0.054688
# 1795   3703  0.301333 -0.251880
# 1794   3702  0.471333 -0.477444
# 1793   3702 -0.130667  0.402256
# 1792   3697  0.000000  0.015038
# 1791   3694  0.317241 -0.208738
# 1790   3694  0.313793 -0.383495
# 1788   3692  0.110345  0.257282
# 904    1811  0.264000 -0.146617
# 1787   3692 -0.065640  0.075342
# 1786   3690  0.269481 -0.229358
# 1546   3185  0.457333 -0.154135
# 907    1816  0.479333 -0.481203
# 906    1816  0.479333 -0.481203
# 905    1812 -0.436667 -0.308271
# 3662   7536 -0.001333  0.462406
#
#                                                     url  strength     emotion  \
# 6     http://s3-ec.buzzfed.com/static/2013-10/enhanc...  0.369731  unpleasant
# 7     http://s3-ec.buzzfed.com/static/2013-10/enhanc...  0.326768   contented
# 3140  http://s3-ec.buzzfed.com/static/2013-11/enhanc...  0.485917      serene
# 3139  http://s3-ec.buzzfed.com/static/2013-11/enhanc...  0.112814     subdued
# 2571  http://s3-ec.buzzfed.com/static/2014-07/29/21/...  0.409152    pleasant
# 2568  http://s3-ec.buzzfed.com/static/2014-07/29/21/...  0.005489    stressed
# 2218  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.496213      elated
# 2217  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.449926       upset
# 2216  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.461855    pleasant
# 2215  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.409704   contented
# 2214  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.157918      active
# 2213  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.480043   contented
# 2204  http://s3-ec.buzzfed.com/static/2013-12/enhanc...  0.456544    pleasant
# 2090  http://s3-ec.buzzfed.com/static/2014-06/29/23/...  0.456522       happy
# 1823  http://s3-ec.buzzfed.com/static/2013-10/enhanc...  0.485891   contented
# 1822  http://s3-ec.buzzfed.com/static/2013-10/enhanc...  0.426531     relaxed
# 1800  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.484514   depressed
# 3150  http://s3-ec.buzzfed.com/static/2014-03/enhanc...  0.457108     nervous
# 3159  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.355148        calm
# 3160  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.351149     relaxed
# 3486  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.488183     relaxed
# 3652  http://s3-ec.buzzfed.com/static/2014-07/16/21/...  0.406591       upset
# 3498  http://s3-ec.buzzfed.com/static/2014-01/enhanc...  0.472881     subdued
# 3490  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.470933     relaxed
# 3489  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.425509      serene
# 3488  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.455951     relaxed
# 3487  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.358058     relaxed
# 3485  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.376715     subdued
# 3161  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.679203     relaxed
# 3484  http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.460955     unhappy
# ...                                                 ...       ...         ...
# 656   http://s3-ec.buzzfed.com/static/2014-09/25/0/e...  0.359870    pleasant
# 630   http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.336680      serene
# 456   http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.430708     relaxed
# 235   http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.456543       tense
# 902   http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.018797     subdued
# 199   http://s3-ec.buzzfed.com/static/2014-02/enhanc...  0.421215       alert
# 198   http://s3-ec.buzzfed.com/static/2014-02/enhanc...  0.310108      serene
# 11    http://s3-ec.buzzfed.com/static/2013-10/enhanc...  0.432519       happy
# 10    http://s3-ec.buzzfed.com/static/2013-10/enhanc...  0.208837     subdued
# 9     http://s3-ec.buzzfed.com/static/2013-10/enhanc...  0.062875   contented
# 8     http://s3-ec.buzzfed.com/static/2013-10/enhanc...  0.377802      serene
# 901   http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.485882   contented
# 903   http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.286110     relaxed
# 1796  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.140498     relaxed
# 1789  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.188656       upset
# 1795  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.392741      serene
# 1794  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.670900     relaxed
# 1793  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.422947       tense
# 1792  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.015038      active
# 1791  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.379754      serene
# 1790  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.495514     relaxed
# 1788  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.279947       alert
# 904   http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.301981      serene
# 1787  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.099925     nervous
# 1786  http://s3-ec.buzzfed.com/static/2014-08/18/18/...  0.353872      serene
# 1546  http://s3-ec.buzzfed.com/static/2013-10/enhanc...  0.482609   contented
# 907   http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.679203     relaxed
# 906   http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.679203     relaxed
# 905   http://s3-ec.buzzfed.com/static/enhanced/webdr...  0.534517     unhappy
# 3662  http://s3-ec.buzzfed.com/static/2014-07/16/20/...  0.462408      active
#
#       Match  N Matches
# 6      True          1
# 7      True          1
# 3140   True          1
# 3139   True          1
# 2571   True          1
# 2568   True          1
# 2218   True          1
# 2217   True          1
# 2216   True          1
# 2215   True          1
# 2214   True          1
# 2213   True          1
# 2204   True          1
# 2090   True          1
# 1823   True          1
# 1822   True          1
# 1800   True          1
# 3150   True          1
# 3159   True          1
# 3160   True          1
# 3486   True          1
# 3652   True          1
# 3498   True          1
# 3490   True          1
# 3489   True          1
# 3488   True          1
# 3487   True          1
# 3485   True          1
# 3161   True          1
# 3484   True          1
# ...     ...        ...
# 656    True          1
# 630    True          1
# 456    True          1
# 235    True          1
# 902    True          1
# 199    True          1
# 198    True          1
# 11     True          1
# 10     True          1
# 9      True          1
# 8      True          1
# 901    True          1
# 903    True          1
# 1796   True          1
# 1789   True          1
# 1795   True          1
# 1794   True          1
# 1793   True          1
# 1792   True          1
# 1791   True          1
# 1790   True          1
# 1788   True          1
# 904    True          1
# 1787   True          1
# 1786   True          1
# 1546   True          1
# 907    True          1
# 906    True          1
# 905    True          1
# 3662   True          1
#
# [72 rows x 25 columns]

# %%
re.sub(r'[^\x00-\x7F]+',' ', 'test\xe2\x80\x99')
# Out:
# 'test '
