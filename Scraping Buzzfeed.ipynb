# %%
from bs4 import BeautifulSoup
import requests

# Given a URL, scrape to get the GIF URL

url = 'http://www.buzzfeed.com/mallorymcinnis/look-at-these-illustrated-gifs-please'

data = []

# Given a BuzzFeed URL, get the GIF URLs and the 
def scrape_buzzfeed(url):
    r = requests.get(url).text
    soup = BeautifulSoup(r)
    print len(soup(attrs={'class': 'buzz_superlist_item'}))
    
scrape_buzzfeed(url)
# Out:
# 0

# %%
import urllib2

page = urllib2.urlopen(url).read()
soup = BeautifulSoup(page)
soup.prettify()
# title = soup.find('title').text
# Out:
# u'<!DOCTYPE HTML>\n<html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">\n <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# buzzfeed: http://ogp.me/ns/fb/buzzfeed#">\n  <title>\n   27 Illustrated GIFs That Will Brighten Even The Most Horrible Day\n  </title>\n  <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>\n  <meta content="Copyright 2014 BuzzFeed, Inc. All rights reserved." name="copyright"/>\n  <meta content="Animations to make you smile no matter how dire the circumstance. .." name="description"/>\n  <meta content="3507663" property="bf:buzzid"/>\n  <meta content="2138524" property="bf:userid"/>\n  <meta content="Mallory McInnis" name="author"/>\n  <meta content="gifs, art, cute, design, happy, illustration" name="news_keywords"/>\n  <meta content="gifs, art, cute, design, happy, illustration" name="sailthru.tags"/>\n  <meta content="app-id=352969997, aff
# ...

# %%
soup.findAll('span')
# Out:
# [<span class="hidden" id="cookie-set-message">
#  				This BuzzFeed homepage is tailored for our readers in the USA.
#  				<a class="bf_dom" href="javascript:;" rel:bf_bucket_data="{'set_country_cookie':{'country':'us'}}" rel:gt_act="set-default-cookie" rel:gt_label="us">Make it your default.</a>
#  </span>, <span class="hidden" id="cookie-us-message">
#  				This BuzzFeed homepage is tailored for our readers in the USA.
#  				<a href="/?country=us">Switch to US</a>
#  </span>, <span class="hidden" id="have-you-seen-message">
#  				Have you seen BuzzFeed English? <a href="/?country=en">Come check it out!</a>
#  </span>, <span class="remove_notice_wrp">
#  <a class="bf_dom remove_notice" href="javascript:;" rel:bf_bucket="remove_cookie_notice" rel:gt_act="remove_cookie_notice" rel:gt_label="us"> </a>
# ...

# %%
soup
# Out:
# <!DOCTYPE HTML>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# buzzfeed: http://ogp.me/ns/fb/buzzfeed#">
# <title>33 GIFs That Will Make You Howl With Laughter Every Single Time</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="Copyright 2014 BuzzFeed, Inc. All rights reserved." name="copyright"/>
# <meta content="Trust us. .." name="description"/>
# <meta content="3494494" property="bf:buzzid"/>
# <meta content="16191" property="bf:userid"/>
# <meta content="Dave Stopera, Jack Shepherd" name="author"/>
# <meta content="" name="news_keywords"/>
# <meta content="" name="sailthru.tags"/>
# <meta content="app-id=352969997, affiliate-data=at=10l3HP&amp;ct=Buzz/SmartBanner" name="apple-itunes-app"/>
# ...
